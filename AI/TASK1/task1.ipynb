# %% [markdown]
# ![Screenshot 2024-07-03 160149.png](data:image/png;base64,...)

# %%
class studient:
  mydict={}
  def __init__(self,name=None,age=None,grade=None,id=None,email=None):
    self.name=name
    self.age=age
    self.grade=grade
    self.id=id
    self.email=email

    if name is None or age is None or grade is None or id is None or email is None:
     raise ValueError("All fields are required")

    if not isinstance(name,str):
      raise TypeError("Name must be a string")
    if not isinstance(email,str):
      raise TypeError("Email must be a string")
    if not isinstance(age,int):
      raise TypeError("Age must be an integer")
    if not isinstance(grade,int):
      raise TypeError("Grade must be an integer")
    if not isinstance(id,int):
      raise TypeError("ID must be an integer")

    studient.mydict[self.name]=self.grade

  def __str__(self):
    return f"Name: {self.name}, Age: {self.age}, Grade: {self.grade}, ID: {self.id}, Email: {self.email}"

  @classmethod
  def get_max_grade(cls):
    maximum=list(cls.mydict.values())[0]
    for i in cls.mydict.values():
      if i>maximum:
        maximum=i
    return maximum


  @classmethod
  def max_grade(cls):
    return max(cls.mydict.values())

  @classmethod
  def average(cls):
    return sum(cls.mydict.values())/len(cls.mydict)

# %%
mahmoud=studient('mahmoud',20,30,'0245566541','mahmoudkhaled@gmail,com')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-149-fb52db065ba3> in <cell line: 1>()
# ----> 1 mahmoud=studient('mahmoud',20,30,'30107171702171','mahmoudkhaled@gmail,com')
#
# <ipython-input-148-d47837eaa46f> in __init__(self, name, age, grade, id, email)
#      20       raise TypeError("Grade must be an integer")
#      21     if not isinstance(id,int):
# ---> 22       raise TypeError("ID must be an integer")
#      23
#      24     studient.mydict[self.name]=self.grade
#
# TypeError: ID must be an integer

# %%
mahmoud=studient('mahmoud',20,30,55606565,'mahmoudkhaled@gmail,com')
amr=studient('amr',20,40,5450454054,'mahmoudkhaled@gmail,com')
basnat=studient('basnat',20,60,454540,'mahmoudkhaled@gmail,com')
khaled=studient('khaled',20,70,90960560,'mahmoudkhaled@gmail,com')
mohamed=studient('mohamed',20,80,5650656,'mahmoudkhaled@gmail,com')
hassan=studient('hassan',20,90,556506550,'mahmoudkhaled@gmail,com')

# %%
print(f'max grade is {studient.get_max_grade()}')
print(f'average grade is {studient.average()}')
# Out:
# max grade is 90
# average grade is 61.666666666666664
