# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahmoudkhaled17/Copy-of-the-boston-houseprice-data/blob/main/the_boston_houseprice_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b43c66cd-af6a-4ace-8d43-b925e513aefd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b43c66cd-af6a-4ace-8d43-b925e513aefd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b1b00b5f-95fd-4b44-8afc-e2d39284bc78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1b00b5f-95fd-4b44-8afc-e2d39284bc78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
! pip install kaggle
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets download -d fedesoriano/the-boston-houseprice-data
# Out:
# ...
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# ...
# Dataset URL: https://www.kaggle.com/datasets/fedesoriano/the-boston-houseprice-data
# License(s): copyright-authors
# ...
#   0% 0.00/12.3k [00:00<?, ?B/s]
# 100% 12.3k/12.3k [00:00<00:00, 23.4MB/s]

# %%
! unzip the-boston-houseprice-data.zip
# Out:
# Archive:  the-boston-houseprice-data.zip
#   inflating: boston.csv

# %%
import pandas as pd
df = pd.read_csv('/content/boston.csv')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# ## EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %% [markdown]
# * all flaot or int data type

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# * there are outliyer

# %%
import seaborn as sns
sns.boxplot(df['MEDV'])
# Out:
# <Axes: ylabel='MEDV'>

# %%
for col in df.columns:
  sns.boxplot(df[col])
  plt.show()

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.value_counts()
# Out:
# CRIM      ZN    INDUS  CHAS  NOX    RM     AGE    DIS      RAD  TAX    PTRATIO  B       LSTAT  MEDV
# 0.00632   18.0  2.31   0     0.538  6.575  65.2   4.0900   1    296.0  15.3     396.90  4.98   24.0    1
# 1.00245   0.0   8.14   0     0.538  6.674  87.3   4.2390   4    307.0  21.0     380.23  11.98  21.0    1
# 1.38799   0.0   8.14   0     0.538  5.950  82.0   3.9900   4    307.0  21.0     232.60  27.71  13.2    1
# 1.35472   0.0   8.14   0     0.538  6.072  100.0  4.1750   4    307.0  21.0     376.73  13.04  14.5    1
# 1.34284   0.0   19.58  0     0.605  6.066  100.0  1.7573   5    403.0  14.7     353.89  6.43   24.3    1
#                                                                                                       ..
# 0.11027   25.0  5.13   0     0.453  6.456  67.8   7.2255   8    284.0  19.7     396.90  6.73   22.2    1
# 0.10959   0.0   11.93  0     0.573  6.794  89.3   2.3889   1    273.0  21.0     393.45  6.48   22.0    1
# ...

# %%
df['CHAS'].value_counts()
# Out:
# CHAS
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
df['RAD'].value_counts()
# Out:
# RAD
# 24    132
# 5     115
# 4     110
# 3      38
# 6      26
# 2      24
# 8      24
# 1      20
# 7      17
# Name: count, dtype: int64

# %%
for col in df.columns:
  sns.histplot(df[col],kde=True)
  plt.show()

# %%
for col in df.drop('MEDV',axis=1).columns:
  plt.scatter(df[col],df['MEDV'])
  plt.xlabel(col)
  plt.ylabel('MEDV')
  plt.show()

# %% [markdown]
# ## DATA PROCESSING

# %%
q1 = df['MEDV'].quantile(0.25)
q3 = df['MEDV'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
df_filtered = df[((df['MEDV'] >= lower_bound) & (df['MEDV'] <= upper_bound))]

# %%
for i in [0,1,2,3,4,5,7,8,9,10,11,12,13]:
  q1=df_filtered.iloc[:,i].quantile(0.25)
  q3=df_filtered.iloc[:,i].quantile(0.75)
  iqr=q3-q1
  lower_bound=q1-1.5*iqr
  upper_bound=q3+1.5*iqr
  df_filtered.iloc[:,i]=np.where(df_filtered.iloc[:,i]<upper_bound,df_filtered.iloc[:,i],df_filtered.iloc[:,i].mean())
  df_filtered.iloc[:,i]=np.where(df_filtered.iloc[:,i]>lower_bound,df_filtered.iloc[:,i],df_filtered.iloc[:,i].mean())

# %%
sns.boxplot(df_filtered['MEDV'])
# Out:
# <Axes: ylabel='MEDV'>

# %%
for col in df_filtered.columns:
  sns.boxplot(df_filtered[col])
  plt.show()

# %%
df_filtered.shape
# Out:
# (466, 14)

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
mn=MinMaxScaler()
scaler = StandardScaler()

# %%
df_2=scaler.fit_transform(df_filtered)
df_3=mn.fit_transform(df_filtered)

# %%
df_2=pd.DataFrame(df_2,columns=df_filtered.columns)
df_3=pd.DataFrame(df_3,columns=df_filtered.columns)

# %%
df_2.head()
# Out:
#        CRIM        ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0 -0.705727  1.833216 -1.336816   0.0 -0.160527  0.751502 -0.123732  0.167327
# 1 -0.696089 -0.526427 -0.635435   0.0 -0.748894  0.430074  0.365267  0.608449
# 2 -0.696099 -0.526427 -0.635435   0.0 -0.748894  2.024689 -0.270075  0.608449
# 3 -0.693766 -0.526427 -1.355972   0.0 -0.842692  1.634384 -0.816183  1.159211
# 4 -0.676924 -0.526427 -1.355972   0.0 -0.842692  1.945376 -0.516359  1.159211
#
#         RAD       TAX   PTRATIO         B     LSTAT      MEDV
# 0 -0.987089 -0.695549 -1.832312  0.824811 -1.248144  0.561746
# 1 -0.873232 -1.016283 -0.500884  0.824811 -0.596699  0.174408
# 2 -0.873232 -1.016283 -0.500884  0.579206 -1.396912  2.288627
# 3 -0.759375 -1.135074 -0.021570  0.687827 -1.567603  2.078819
# 4 -0.759375 -1.135074 -0.021570  0.824811 -1.193335  0.032238

# %%
sns.heatmap(df_2.corr(),annot=True)
# Out:
# <Axes: >

# %%
df_2.drop('CHAS',axis=1,inplace=True)
df_2.drop('RAD',axis=1,inplace=True)


df_3.drop('CHAS',axis=1,inplace=True)
df_3.drop('RAD',axis=1,inplace=True)

# %%
sns.heatmap(df_2.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
df_2.drop('B',axis=1,inplace=True)
df_2.drop('NOX',axis=1,inplace=True)
df_2.drop('DIS',axis=1,inplace=True)

df_3.drop('B',axis=1,inplace=True)
df_3.drop('NOX',axis=1,inplace=True)
df_3.drop('DIS',axis=1,inplace=True)

# %%
sns.heatmap(df_2.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.heatmap(df_3.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
from re import X
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df_2.drop('MEDV',axis=1),df_2['MEDV'],test_size=0.2,random_state=42)
x_train2,x_test2,y_train2,y_test2=train_test_split(df_3.drop('MEDV',axis=1),df_3['MEDV'],test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures

# %%
ploy=PolynomialFeatures(degree=2)
x_p=ploy.fit_transform(X_train)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_p,y_train)
# Out:
# LinearRegression()

# %%
r2_score(y_test,model.predict(ploy.fit_transform(X_test)))
# Out:
# 0.7357279369778256

# %%
model2=LinearRegression()
model2.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
r2_score(y_test,model2.predict(X_test))
# Out:
# 0.6879155637335784

# %%
from sklearn.tree import DecisionTreeRegressor
model3=DecisionTreeRegressor()
model3.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
r2_score(y_test,model3.predict(X_test))
# Out:
# 0.5360435314991521

# %%
from sklearn.ensemble import RandomForestRegressor
model4=RandomForestRegressor()
model4.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
r2_score(y_test,model4.predict(X_test))
# Out:
# 0.72268616273926

# %%
from xgboost import XGBRegressor
model5=XGBRegressor()
model5.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
r2_score(y_test,model5.predict(X_test))
# Out:
# 0.701776295352926

# %% [markdown]
# ## minmax

# %%
rf=RandomForestRegressor()
rf.fit(x_train2,y_train2)
# Out:
# RandomForestRegressor()

# %%
r2_score(y_test2,rf.predict(x_test2))
# Out:
# 0.7267255644596401

# %%
xg2=XGBRegressor()
xg2.fit(x_train2,y_train2)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
r2_score(y_test2,xg2.predict(x_test2))
# Out:
# 0.7077682233208593
